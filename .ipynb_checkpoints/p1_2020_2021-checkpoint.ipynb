# %% [markdown]
# # Computer Vision - Laboratory

# %% [markdown]
# ## Practicum 1: Basics on Image Processing and Manipulation
#
# The main topics are:
# 1. Image loading, saving and creation
# 2. Color manipulation
#
# In order to complete this practicum, we will work with the following concepts: image creation, data types, image manipulation.

# %% [markdown]
# ### Packages loading
#
# First we need to import the required Python packages for basic image manipulation.
#
# Run the following code:

# %%
import numpy as np # useful for manipulating matrices
from skimage import io # useful for image loading and saving
from matplotlib import pyplot as plt # useful for plotting images on iPython or Jupyter Notebooks

# %% [markdown]
# Note that commands starting with the percentage sign (`%`) are special internal commands to ipython (as opposed to Python code to be run). In the case below, we set the matplotlib environment to display images results inline (i.e. the images will be shown **inside the
# notebook**):

# %%
# %matplotlib inline

# %% [markdown]
# ### 1.1 Image creation

# %% [markdown]
# Remember that [Numpy](https://docs.scipy.org/doc/numpy-1.13.0/reference/) allows us to define images of different kinds treating them as matrices.
#
# The most common examples are:
#
# * Binary: with values of 0 or 1, interpreted as black or white, respectively.
# * Grayscale: with possible data types uint8, uint16, double, whose pixel values define their intensity.
# * RGB Image: color images consisting of 3 matrices (usually called 'channels'), which contain intensity values for each color separately R (red), G (green) and B (blue).

# %% [markdown]
# a) Create and display a grayscale image that has 150 rows and 200 columns where each value should be of type unsigned integer with 8 bits.

# %%
imgArray = np.zeros((150,200),dtype ='uint8')#Creating 2D matrix with specified type
plt.imshow(imgArray, cmap='gray')

# %% [markdown]
# How many values can each pixel have in this case?

# %%
#Values from 0 to 255, that's 1 byte. We use uint8 for that reason, 8 bits can represent from 0 to 255 in decimal.

# %% [markdown]
# b) Change the color of the pixels of the image in such a way that the left half is black (0) and the right half is white (255).
#
# Visualize the image and print the values of its first row.

# %%
colIteration = (int)(imgArray.shape[1]/2) #Agafem l'index que indica la meitat de la matriu
imgArray[:,colIteration::] = 255  #Posem a blanc la part dreta
plt.imshow(imgArray, cmap='gray')
plt.show()

# %% [markdown]
# ### 1.2 Image saving and loading
#
# a) Use the IO image package to save the image previously created:

# %%
io.imsave('./black_and_white.bmp',imgArray)

# %% [markdown]
# b) Load the saved image and visualize it:

# %%
img = io.imread('./black_and_white.bmp')

plt.imshow(img,'gray') #Visualizing a figure with the image

# %% [markdown]
# ### 1.3 Color image manipulation
#
# a) Load and show the image `lenna.jpg`, and check its dimensions.
#
# **Note:** Pictures may appear in the figure with pseudocolors. Use (imread,im,cmap='rgb') to display them in RGB color and (imread,im,cmap='gray') to display them in grayscale. For more information, check the color maps available in the documentation.

# %%
img = io.imread('./lenna.jpg')

plt.imshow(img,'gray') #Visualizing a figure with the image
print(img.shape)
# Out:
# (225, 400, 3)

# %% [markdown]
# b) Convert the previous image to grayscale, visualize and save it. Moreover, show both images (RGB & greyscale) details such as shape, dtype, max and min values.

# %%
from skimage.color import rgb2gray

img_gray = rgb2gray(img)  #Passem a grayscale
plt.imshow(img_gray, cmap='gray')
plt.show() #Visualitzem

io.imsave('./lenna_gray.bmp',img_gray)#Guardem la imatge a la carpeta

#Mostrem valors de las dos imatges
print("RGB image details:", img.shape, img.dtype, img.max(), img.min())
print("Greyscale image details", img_gray.shape, img_gray.dtype, np.round(img_gray.max(),5), np.round(img_gray.min(),5))
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# RGB image details: (225, 400, 3) uint8 255 0
# Greyscale image details (225, 400) float64 0.98699 0.00141

# %% [markdown]
# c) Convert the lena image into a boolean image, by applying a binarization to the grayscale image. This should be done by setting to 0 all values equal or below 100 and to 1 otherwise. Check the range of the values of the image, and print the 10th row.

# %%
print(img.shape)

im_bin = io.imread('./lenna_gray.bmp')#Agafem la imatge graysacle que tenim i binaritzem
#Binaritzem els valors
im_bin[(im_bin<=100)] = 0
im_bin[(im_bin>100)] = 1
io.imsave('./lenna_bin.bmp',im_bin) #Guardem la imatge binaria
plt.imshow(im_bin, cmap='binary')
# Out:
# (225, 400, 3)
# /home/danielyeste/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: ./lenna_bin.bmp is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %% [markdown]
# d) Visualize in the same figure three images: (1) the original image, (2) the graylevel image, and (3) the binarized image. Set the corresponding titles of the images.

# %%
img = io.imread('./lenna.jpg')
img_gray = io.imread('./lenna_gray.bmp')
im_bin = io.imread('./lenna_bin.bmp')


plt.title('ORIGINAL')
plt.imshow(img)
plt.show()

plt.title('GRAYSCALED')
plt.imshow(img_gray,cmap='gray')
plt.show()

plt.title('BYNARIZED')
plt.imshow(im_bin,cmap='binary')
plt.show()

# %% [markdown]
# ### 1.4 Images manipulation
#
# a) Add a black frame to Lenna's image. It should have a width of 1/10th of the height of the original image. We recommend to create a bigger black image to later embed the original image in the central part.

# %%
def create_frame(im,width): #Creem un métode per crear marcs més fácilment per qualsevol imatge

    if len(im.shape) == 3:  #Cas RGB
         #Creem el frame amb unes mesures algo majors que la imatge, per així fer un contorn amb les mesures que indica l'enunciat
        frame = np.zeros((im.shape[0]+(2*width),im.shape[1]+(2*width),3), dtype = 'uint8')
    else: #CAS GRAYSCALE
        frame = np.zeros((im.shape[0]+(2*width),im.shape[1]+(2*width)), dtype = 'uint8')
        
    #Insertem la imatge dins el frame
    frame[width:frame.shape[0]-width,width:frame.shape[1]-width] = im
    
    return frame

im = io.imread('./lenna.jpg')
width = int(im.shape[0]/10) #Width que indica l'enunciat
frame = create_frame(im,width)

plt.imshow(frame)
plt.show()

# %% [markdown]
# b) Change the mask of the framed image to red. Visualize the three images with their respective titles.

# %%
#Fem slice utilizant la variable frame_width per saber fins quina posició em de posar a vermell
def color_frame(frame,color):  #Métode per posar color al frame
    frame[:,:width] = color  #MArge esquerre
    frame[:,frame.shape[1]-width:] = color #Marge dret
    frame[:width, :] = color #Marge dalt
    frame[width+im.shape[0]::,:] = color #Marge baix
    
    return frame

frame = color_frame(frame,[255,0,0])

plt.imshow(frame)
plt.show()

# %%
#Original
im = io.imread('./lenna.jpg')
frame_width = int(im.shape[0]/10)
im = create_frame(im,frame_width)
im = color_frame(frame,[255,0,0])

#Grey
img_gray = io.imread('./lenna_gray.bmp')
frame_width = int(img_gray.shape[0]/10)
img_gray = create_frame(img_gray,frame_width)

#Binary
img_bin = io.imread('./lenna_bin.bmp')
frame_width = int(im_bin.shape[0]/10)
img_bin = create_frame(img_bin, frame_width)


#Mostrem imatges
plt.title('ORIGINAL')
plt.imshow(im)
plt.show()
plt.title('GRAYSCALED')
plt.imshow(img_gray, cmap='gray')
plt.show()
plt.title('BINARY IMAGE')
plt.imshow(img_bin, cmap='binary')
plt.show()

# %% [markdown]
# ### 1.5 Contrast enhancement
#
# a) Open the image `car_lowContrast.jpg` and visualize it without graylevel enhancement. To this purpose, check which are the minimal and maximal values and how to use the command imshow without contrast enhancement.
#
# Note: When running the function `imshow()` the image is authomatically enhanced. Use the `vmin` and `vmax` parameters in order to deactivate the enhancement applied by default.

# %%
imgCar = io.imread('./car_lowContrast.jpg')
#By default the image is show with vmin = imgCar.min/vmax = imgCar.max, we change it in order to deactivate the
#default enhancement.
plt.imshow(imgCar,cmap = 'gray',vmin = 0,vmax = 255)
print("Min value",imgCar.min())
print("Max value",imgCar.max())
# Out:
# Min value 63
# Max value 193

# %% [markdown]
# b) Create an image called `dark_image` using the  values from the original one, so that the minimal value of the new image is 0. Check the minimal and maximal values of the new image, and compare them with the previous one.

# %%
dark_image = imgCar.copy()
dark_image -= imgCar.min()
#We subtract the min value from each value in the array so the new minimum value is 0 and all the other values are
#set to value-imgCar.min()
plt.imshow(dark_image,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
print("Min value",dark_image.min())
print("Max value",dark_image.max())
# Out:
# Min value 0
# Max value 130

# %% [markdown]
# c) Create a new image called `bright_im` from the original one, so that the maximal value of the new image is 255. Check the minimal and maximal values of the new image, and compare them with the previous one.

# %%
bright_im = imgCar.copy()
bright_im += (255-imgCar.max())
#We sum 255- max value from each value in the array so the new maximum value is 255 and all the other values are
#set to value+(255-imgCar.max())
plt.imshow(bright_im,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
print("Min value",bright_im.min())
print("Max value",bright_im.max())
# Out:
# Min value 125
# Max value 255

# %% [markdown]
# d) Apply contrast enhancement to the original image. There are two ways for it: (1) by direct manipulation, and (2) through scikit-image command. Check the minimal and maximal values of the enhanced image, and compare them with the previous one.
#
# Implement the contrast enhancement using the two different available methods.

# %%
from skimage import exposure
imgCarCopy = imgCar.copy()
imgCarContrastByManipulation = (imgCarCopy-imgCarCopy.min())*1/(imgCarCopy.max()-imgCarCopy.min())#Direct array manipulation
plt.imshow(imgCarContrastByManipulation,cmap = 'gray',vmin = 0,vmax = 1) #Visualizing a figure with the image
print("Min value",imgCarContrastByManipulation.min())
print("Max value",imgCarContrastByManipulation.max())
# Out:
# Min value 0.0
# Max value 1.0

# %%
imgCarContrastByFunction = exposure.adjust_sigmoid(imgCar)#Used to enhance the contrast
plt.imshow(imgCarContrastByFunction,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
print("Min value",imgCarContrastByFunction.min())
print("Max value",imgCarContrastByFunction.max())
# Out:
# Min value 18
# Max value 236

# %% [markdown]
# e) Visualize the 5 images in the same figure, each one with its corresponding title.

# %%
print("ORIGINAL IMAGE")
plt.imshow(imgCar,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
plt.show()
print("DARK IMAGE")
plt.imshow(dark_image,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
plt.show()
print("BRIGHT IMAGE")
plt.imshow(bright_im,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
plt.show()
print("ENHANCED CONTRAST IMAGE BY MANIPULATION")
plt.imshow(imgCarContrastByManipulation,cmap = 'gray',vmin = 0,vmax = 1) #Visualizing a figure with the image
plt.show()
print("ENHANCED CONTRAST IMAGE BY FUNCTION")
plt.imshow(imgCarContrastByFunction,cmap = 'gray',vmin = 0,vmax = 255) #Visualizing a figure with the image
plt.show()
# Out:
# ORIGINAL IMAGE
# DARK IMAGE
# BRIGHT IMAGE
# ENHANCED CONTRAST IMAGE BY MANIPULATION
# ENHANCED CONTRAST IMAGE BY FUNCTION

# %% [markdown]
# ### 1.6 Masks and logical image manipulation
#
# Read the image `circles.bmp` (see figure top) and define 3 images in such a way that each one contains only 1 ball (see figure bottom). Visualize the 3 images in the same figure, each one with its corresponding title.
#
# <img src="images_notebook/ex16.png">
#
# **Note:** Be careful when applying `imshow` since it automatically increases the contrast of the image (putting minimum values to 0 and maximal to 1).
#
# **Note:** Be careful when applying type conversion. Check the ranges of the image values.

# %%
#Your solution
#Cercar els pixels amb el rang de valors que corresponen a cada cercle. 
circles = io.imread('./circles.bmp')

print(circles[500,200])  #Veiem els color rgb del cercle esquerre(negre)
print(circles[500,500])  #Veiem els color rgb del cercle central(gris fort)
print(circles[500,800])  #Veiem els color rgb del cercle dret(gris fluix)
#Sabent quins valors té cada cercle, podem crear las novees figures amb el mateix color, falta trobar las coordenades exactes

#Creem màscara cercle negre 
negre = np.zeros(circles.shape, dtype='uint8')
negre[:,:,:] =[255,255,255] #Posem la imatge a blanc
mask1 = circles[:,:] == [0,0,0] #Trobem els pixels de la imatge original que valen [0,0,0] amb la condicio booleana
negre[mask1] = circles[mask1]  #CReem la figura amb nomes el cercle negre, a partir de la màscara creada


#Fem el mateix que anteriorment per tenir cercle central i dret

#Cercle central
gris_fosc = np.zeros(circles.shape, dtype='uint8')
gris_fosc[:,:,:] = [255,255,255]
mask2 = circles[:,:] == [127,127,127]
gris_fosc[mask2] = circles[mask2]



#Cercle dret
gris_fluix = np.zeros(circles.shape, dtype='uint8')
gris_fluix[:,:,:] = [255,255,255]
mask3 = circles[:,:] == [195,195,195]
gris_fluix[mask3] = circles[mask3]

#Mostrem les 3 imatges en la mateixa figura
plt.subplot(1,3,1)
plt.title("Left circle")
plt.imshow(negre)
plt.subplot(1,3,2)
plt.title("Central circle")
plt.imshow(gris_fosc)
plt.subplot(1,3,3)
plt.title("Right circle")
plt.imshow(gris_fluix)
plt.show()
# Out:
# [0 0 0]
# [127 127 127]
# [195 195 195]

# %% [markdown]
# ### 1.7 Color manipulation
#
# a) Create and visualize the three images shown in the following figure:
# <img src="./images_notebook/ex17a.png">

# %%
#Your solution
#Primera imatge
im1 = np.zeros((200,200,3),dtype='uint8')
im1[:,101:]=[255,255,255]

#Segona imatge
im2 = np.zeros((200,200,3),dtype='uint8')
im2[101:,:] = [255,255,255]

#Tercera imatge
im3 = np.zeros((200,200,3),dtype='uint8')
im3[:101,:101] = [255,255,255]

#Mostrem imatges
plt.subplot(1,3,1)
plt.imshow(im1)

plt.subplot(1,3,2)
plt.imshow(im2)

plt.subplot(1,3,3)
plt.imshow(im3)

plt.show()

# %% [markdown]
# b) Using these three images, construct the following color image:
# <img src='./images_notebook/ex17b.png'>

# %%
#En lugar de utilizar el color blanco lo substituimos por colores primarios en las posiciones correspondientes.
#Así, sumando las tres matrices se combinaran de manera que cree la imagen deseada
im1Color = np.zeros((200,200,3),dtype='uint8')#Primera imagen con color R
im1[:,101:]=[255,0,0]
im2Color = np.zeros((200,200,3),dtype='uint8')#Segunda imagen con color G
im2[101:,:] = [0,255,0]
imColor3 = np.zeros((200,200,3),dtype='uint8')#Tercera imagen con color B
im3[:101,:101] = [0,0,255]
colorImg = im1+im2+im3
plt.imshow(colorImg)
plt.show()

# %% [markdown]
# c) Read and visualize the image `sillas.jpg` (see figure top). Extract its three channels and visualize them in the same figure with their respective titles (see the figure bottom).
# <img src="images_notebook/ex17c.png">
#
# <img src="images_notebook/ex17c2.png">

# %%
#Your solution
sillas = io.imread('./sillas.jpg')
r_sillas = sillas[:,:,0]  #Agafem nomes el canal red
g_sillas = sillas[:,:,1]
b_sillas = sillas[:,:,2]

plt.subplot(1,3,1)
plt.title("Red channel")
plt.imshow(r_sillas, cmap='gray')

plt.subplot(1,3,2)
plt.title("Green channel")
plt.imshow(g_sillas, cmap='gray')

plt.subplot(1,3,3)
plt.title("Blue channel")
plt.imshow(b_sillas, cmap='gray')

plt.show()

# %% [markdown]
# d) Construct and visualize a new image in which the red color of the chairs is changed to blue (see figure).
# <img src="images_notebook/ex17c3.png">

# %%
#Your solution
chairBlue = sillas.copy()
chairBlue[:,:,0],chairBlue[:,:,2] = sillas[:,:,2],sillas[:,:,0] #Intercambiamos los canales rojo y azul, de esta forma donde predomina rojo cambia a azul
plt.imshow(chairBlue,cmap = 'gray',vmin = 0,vmax= 255)
plt.imshow(chairBlue)
plt.show()

# %% [markdown]
# e) Given the images `coat.png` and `model.png` (first two images on the figure below), implement the necessary code to construct the image of the model with the coat (third image). Next find in internet an image with a texture and apply it to obtain an image of the jacket with the found texture (fourth image is only an example).
#
# <img src="images_notebook/ex17d.png">
#
# **Note:** when applying resize, rotate, etc. keep track how the image type and values range change. When necessary, apply type conversion using img_as_float, img_as_uint, img_as_ubyte.

# %%
from skimage.color import rgba2rgb
from skimage.transform import resize
from skimage import img_as_float

coat = io.imread('./coat.png')
model = io.imread('./model.png')
#Passem les imatges a rgb
coat = rgba2rgb(coat)
model = rgba2rgb(model)

mask = coat[:,:]>0 #Creem una màscara per saber les coordenades on esta la jaqueta
model[mask] = coat[mask] #Apliquem la màscara a la model 
plt.imshow(model)
plt.show()

#Cargamos la textura
texture = io.imread('./texture.jpg')
texture = img_as_float(resize(texture,model.shape)) #Hacemos resize de la textura para que sea igual a la modelo i aplicar la misma màscara
model[mask] = texture[mask]


plt.imshow(model)
plt.show()

# %% [markdown]
# ## Delivery
#
# Compressed file **P1_Student1_Student2.zip** that includes:
# - The notebook P1_Student1_Student2.ipynb completed with the solutions to the exercises and their corresponding comments.
# - The images used that are not provided in P1.zip.
#
# **Deadline (Campus Virtual): October 13, 11:00 p.m.**
